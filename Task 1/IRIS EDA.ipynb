# %% [markdown]
# #  Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')
# %matplotlib inline

# %% [markdown]
# # Load the dataset

# %%
#load data for processing 
iris=pd.read_csv("iris.csv")

# %% [markdown]
# # Preprocessing steps

# %%
# column names in our dataset
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#view the dataset 
#to view the data from starting we use .head(), by default its shows top 5 entry 
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#to view the dataset from last use .tail()
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# no. of data points for each class
# no. of flower for each species
#balanced dataset 
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
#viewing number of columns and rows.(ROW,column)
#Which return a tuple value of rows and columns
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# # Dataset description

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.sample(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 105           7.6          3.0           6.6          2.1   virginica
# 52            6.9          3.1           4.9          1.5  versicolor
# 50            7.0          3.2           4.7          1.4  versicolor
# 48            5.3          3.7           1.5          0.2      setosa
# 123           6.3          2.7           4.9          1.8   virginica
# 133           6.3          2.8           5.1          1.5   virginica

# %%
# central tendency of iris dataset
iris.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.054000      3.758667     1.198667     NaN
# std         0.828066     0.433594      1.764420     0.763161     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris_setosa = iris.loc[iris["species"]=="setosa"]
iris_setosa.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
iris_versicolor = iris.loc[iris["species"]=="versicolor"]
iris_versicolor.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
iris_virginica = iris.loc[iris["species"]=="virginica"]
iris_virginica.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
# mean of iris dataset...
np.mean(iris)
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
# maximum value obtained...
np.max(iris)
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %%
# minimum value obtained
np.min(iris)
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         setosa
# dtype: object

# %% [markdown]
# # Visualization of data

# %%
#2-D Scatter Plot
iris.plot('sepal_length','sepal_width',kind='scatter')
plt.show()

# %%
iris.plot('petal_length','petal_width',kind='scatter')
plt.show()

# %%
iris_setosa = iris.loc[iris["species"] == "setosa"]
iris_virginica = iris.loc[iris["species"] == "virginica"]
iris_versicolor = iris.loc[iris["species"] == "versicolor"]

# %%
iris_setosa.plot(x="sepal_length", y="sepal_width", kind="scatter", label='setosa',color='r')
iris_versicolor.plot(x="sepal_length",y="sepal_width",kind="scatter", label='versicolor',color='b')
iris_virginica.plot(x="sepal_length", y="sepal_width", kind="scatter", label='virginica', color='g')
plt.show()

# %%
#here we can see the blue is making cluster but 
#green and orange is overlapping 

sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", size=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend();
plt.show();

# %%
#Pair plot :Can be used when number of features are high
#Only possible to view 2D patterns.
plt.close()
sns.set_style('whitegrid');
sns.pairplot(iris, hue="species", markers=["o", "s", "D"], palette="husl")

# %%
#other variation of pair plot :
sns.set_style('whitegrid')
sns.pairplot(iris,hue='species',size=4)

# %%
#1d scatter plot :he data points are overlapping and it is difficult to seperate the points
iris_setosa = iris.loc[iris["species"] == "setosa"]
iris_versicolor = iris.loc[iris["species"] == "versicolor"]
iris_virginica = iris.loc[iris["species"] == "virginica"]

plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']), 'o')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']), 'o')
plt.legend(['Setosa', 'Versicolor', 'Virginica'])
plt.xlabel('Petal_Length')
plt.title('1D plot')

plt.show()

# %%
sns.FacetGrid(iris,hue='species',size=5).map(sns.distplot,"petal_length").add_legend()
plt.show()

# %%
sns.FacetGrid(iris,hue='species',size=5).map(sns.distplot,'sepal_length')

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "sepal_length") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "sepal_width") \
   .add_legend();
plt.title("Histogram")
plt.show();

# %%
# We can visually see what percentage of versicolor flowers have a 
# petal_length of less than 1.6?
#Plot CDF of petal_length

counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, 
                                density = True)
fig = plt.figure(figsize=(5, 5))
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)
plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
counts,x=np.histogram(iris_setosa['petal_length'],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)

cdf=np.cumsum(pdf)
plt.plot(pdf)
plt.plot(cdf)
plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]

# %%
# Plots of CDF of petal_length for various types of flowers.

# Misclassification error if you use petal_length only.
plt.style.use('seaborn-whitegrid')
counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=5,density = True)
#fig = plt.figure(figsize=(10, 10))
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

# virginica
counts, bin_edges = np.histogram(iris_virginica['petal_length'], bins=5,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

#versicolor
counts, bin_edges = np.histogram(iris_versicolor['petal_length'], bins=5,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.04 0.18 0.52 0.22 0.04]
# [1.   1.18 1.36 1.54 1.72 1.9 ]
# [0.12 0.32 0.34 0.14 0.08]
# [4.5  4.98 5.46 5.94 6.42 6.9 ]
# [0.06 0.1  0.3  0.32 0.22]
# [3.   3.42 3.84 4.26 4.68 5.1 ]

# %% [markdown]
# # Mean, Variance and Standard Deviation

# %%
#Mean, Variance, Std-deviation,  
print("Means:")
print(np.mean(iris_setosa["petal_length"]))
#Mean with an outlier.
print(np.mean(np.append(iris_setosa["petal_length"],50)));
print(np.mean(iris_virginica["petal_length"]))
print(np.mean(iris_versicolor["petal_length"]))

print("\nStd-dev:");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# Means:
# 1.464
# 2.4156862745098038
# 5.552
# 4.26
#
# Std-dev:
# 0.17176728442867115
# 0.5463478745268441
# 0.4651881339845204

# %% [markdown]
# # Median, Percentile, Quantile, IQR, MAD

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print(np.median(iris_setosa["petal_length"]))
#Median with an outlier
print(np.median(np.append(iris_setosa["petal_length"],50)));
print(np.median(iris_virginica["petal_length"]))
print(np.median(iris_versicolor["petal_length"]))

print("\nQuantiles:")
print(np.percentile(iris_setosa["petal_length"],np.arange(0, 100, 25)))
print(np.percentile(iris_virginica["petal_length"],np.arange(0, 100, 25)))
print(np.percentile(iris_versicolor["petal_length"], np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print(np.percentile(iris_setosa["petal_length"],90))
print(np.percentile(iris_virginica["petal_length"],90))
print(np.percentile(iris_versicolor["petal_length"], 90))

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(iris_setosa["petal_length"]))
print(robust.mad(iris_virginica["petal_length"]))
print(robust.mad(iris_versicolor["petal_length"]))
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th Percentiles:
# 1.7
# 6.3100000000000005
# 4.8
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# # Box-plot

# %%
#Box-plot : use for continous variable.string tell us max/min points & outlier ,Box tells median 
#Box-plot can be visualized as a PDF on the side-ways
# IQR like idea.
#NOTE: IN the plot below, a technique call inter-quartile range is used in plotting the whiskers
sns.boxplot(x='species',y='petal_length', data=iris)
plt.show()

# %%
plt.close()
#fig = plt.figure(figsize=(8, 8))
plt.style.use('ggplot')
sns.set(style="whitegrid")
sns.boxplot(x='species',y='petal_length', hue = 'species', data=iris)

# %%
#plotting with axis =1 :
sns.boxplot(data = iris.drop(['species'],axis=1))

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
sns.boxplot(x="species",y="sepal_length",data=iris)
plt.subplot(2,2,2)
sns.boxplot(x="species",y="sepal_width",data=iris)
plt.subplot(2,2,3)
sns.boxplot(x="species",y="petal_length",data=iris)
plt.subplot(2,2,4)
sns.boxplot(x="species",y="petal_width",data=iris)

# %% [markdown]
# # Heat map

# %%
plt.figure(figsize=(11,11))
sns.heatmap(iris.corr(),annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# # Violin plot

# %%
# A violin plot combines the benefits of the previous two plots and simplifies them
# Denser regions of the data are fatter, and sparser ones thinner in a violin plot
#The thinner part denotes that there is less density whereas the fatter part conveys higher density

sns.violinplot(x="species", y="petal_length", data=iris, size=8)
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
sns.violinplot(x="species",y="sepal_length",data=iris)
plt.subplot(2,2,2)
sns.violinplot(x="species",y="sepal_width",data=iris)
plt.subplot(2,2,3)
sns.violinplot(x="species",y="petal_length",data=iris)
plt.subplot(2,2,4)
sns.violinplot(x="species",y="petal_width",data=iris)

# %% [markdown]
# # lmplot

# %%
sns.lmplot(x='sepal_length',y='petal_length',data=iris,hue='species')

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(x='species',y='sepal_length',data=iris,hue='species')

# %%
plt.figure(figsize=(15,15))
plt.subplot(4,4,1)
sns.swarmplot(x='species',y='sepal_length',data=iris,hue='species')
plt.subplot(4,4,2)
sns.swarmplot(x='species',y='sepal_width',data=iris,hue='species')
plt.subplot(4,4,3)
sns.swarmplot(x='species',y='petal_length',data=iris,hue='species')
plt.subplot(4,4,4)
sns.swarmplot(x='species',y='petal_width',data=iris,hue='species')

# %% [markdown]
# # Violin Plots with Swarm Plots

# %%
plt.close()
fig = plt.figure(figsize=(8, 8))
sns.violinplot(x="species", y="petal_length", data=iris)
sns.swarmplot(x="species", y="petal_length",  hue = 'species', data=iris, color=".1")

# %% [markdown]
# # Barplot

# %%
sns.barplot(x='species',y='sepal_length',data=iris)

# %%
#sepal_length sepal_width  petal_length  petal_width 

plt.figure(figsize=(16,16))
#plot
plt.subplot(4,4,1)
sns.barplot(x='species',y='sepal_length',data=iris,hue='species')
plt.subplot(4,4,2)
sns.barplot(x='species',y='sepal_width',data=iris,hue='species')
plt.subplot(4,4,3)
sns.barplot(x='species',y='petal_length',data=iris,hue='species')
plt.subplot(4,4,4)
sns.barplot(x='species',y='petal_width',data=iris,hue='species')

# %% [markdown]
# # Contour plot

# %%
sns.jointplot(x="petal_length", y="petal_width", data=iris_setosa, kind="kde")
plt.show()
